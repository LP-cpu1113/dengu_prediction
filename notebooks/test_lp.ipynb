# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv('data/dengue_features_train.csv')
df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
df_labels= pd.read_csv('data/dengue_labels_train.csv')
df_labels.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
df_merge= df.merge(
    df_labels,
    on=['city', 'year', 'weekofyear']
)
df_merge.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# ...

# %%
df_merge["type"]="train"

# %%
df_merge.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# ...

# %%
df_test= pd.read_csv('data/dengue_features_test.csv')

# add type column
df_test['type'] = 'test'


# combine both tables
df_all = pd.concat(
    [df_merge, df_test],
    ignore_index=True
)

df_all.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# ...

# %%
df_all.shape
# Out:
# (1872, 26)

# %%
df.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
# week_start_date as string to date time

df['week_start_date'] = pd.to_datetime(df['week_start_date'])

df.dtypes
# Out:
# city                                                str
# year                                              int64
# weekofyear                                        int64
# week_start_date                          datetime64[us]
# ndvi_ne                                         float64
# ndvi_nw                                         float64
# ndvi_se                                         float64
# ndvi_sw                                         float64
# precipitation_amt_mm                            float64
# reanalysis_air_temp_k                           float64
# reanalysis_avg_temp_k                           float64
# reanalysis_dew_point_temp_k                     float64
# reanalysis_max_air_temp_k                       float64
# reanalysis_min_air_temp_k                       float64
# reanalysis_precip_amt_kg_per_m2                 float64
# reanalysis_relative_humidity_percent            float64
# reanalysis_sat_precip_amt_mm                    float64
# ...

# %%
df.shape
# Out:
# (1456, 24)

# %%
df.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %%
#convert week_start_date and deleted_date to datetime.
#df[['created_date','deleted_date']].apply(
#    lambda _: pd.to_datetime(_,infer_datetime_format=True, errors='coerce'))

#create the live_days column.
#df['live_days'] = (df['deleted_date'] - df['created_date']).dt.days

df.describe()
# Out:
#               year   weekofyear             week_start_date      ndvi_ne  \
# count  1456.000000  1456.000000                        1456  1262.000000
# mean   2001.031593    26.503434  2001-07-09 16:01:19.120879     0.142294
# min    1990.000000     1.000000         1990-04-30 00:00:00    -0.406250
# 25%    1997.000000    13.750000         1997-04-28 06:00:00     0.044950
# 50%    2002.000000    26.500000         2002-05-28 00:00:00     0.128817
# 75%    2005.000000    39.250000         2005-11-26 00:00:00     0.248483
# max    2010.000000    53.000000         2010-06-25 00:00:00     0.508357
# std       5.408314    15.019437                         NaN     0.140531
#
#            ndvi_nw      ndvi_se      ndvi_sw  precipitation_amt_mm  \
# count  1404.000000  1434.000000  1434.000000           1443.000000
# mean      0.130553     0.203783     0.202305             45.760388
# min      -0.456100    -0.015533    -0.063457              0.000000
# ...

# %%
df.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm'],
#       dtype='str')

# %%
# missing vales to mean

cols = ['ndvi_sw', 'ndvi_ne', 'ndvi_se', 'ndvi_nw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
       'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
       'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
       'reanalysis_precip_amt_kg_per_m2',
       'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
       'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
       'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
       'station_min_temp_c', 'station_precip_mm']

#df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df[cols] = df[cols].fillna(df[cols].mean())

# %%
df.describe()
# Out:
#               year   weekofyear             week_start_date      ndvi_ne  \
# count  1456.000000  1456.000000                        1456  1456.000000
# mean   2001.031593    26.503434  2001-07-09 16:01:19.120879     0.142294
# min    1990.000000     1.000000         1990-04-30 00:00:00    -0.406250
# 25%    1997.000000    13.750000         1997-04-28 06:00:00     0.055625
# 50%    2002.000000    26.500000         2002-05-28 00:00:00     0.142294
# 75%    2005.000000    39.250000         2005-11-26 00:00:00     0.229292
# max    2010.000000    53.000000         2010-06-25 00:00:00     0.508357
# std       5.408314    15.019437                         NaN     0.130827
#
#            ndvi_nw      ndvi_se      ndvi_sw  precipitation_amt_mm  \
# count  1456.000000  1456.000000  1456.000000           1456.000000
# mean      0.130553     0.203783     0.202305             45.760388
# min      -0.456100    -0.015533    -0.063457              0.000000
# ...

# %%
df['city'].unique()
# Out:
# <StringArray>
# ['sj', 'iq']
# Length: 2, dtype: str

# %%
# cities to numbers

df_all['city'] = df_all['city'].replace({
    'sj': 0,
    'iq': 1
})
df_all.city
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1867    1
# 1868    1
# 1869    1
# 1870    1
# 1871    1
# Name: city, Length: 1872, dtype: object

# %%
df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0    0  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1    0  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2    0  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3    0  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4    0  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
# 0-sj, 1-iq

import matplotlib.pyplot as plt

# convert date
df['week_start_date'] = pd.to_datetime(df['week_start_date'])

# NDVI columns
ndvi_cols = ['ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw']

# create 2 graphs (1 per city)
fig, axes = plt.subplots(2, 1, figsize=(15,10))

# loop through cities
for ax, city in zip(axes, df['city'].unique()):
    
    temp = df[df['city'] == city].sort_values('week_start_date')
    
    # plot all 4 NDVI features
    for col in ndvi_cols:
        ax.plot(temp['week_start_date'], temp[col], label=col)
    
    ax.set_title(f'NDVI Features for {city}')
    ax.set_xlabel('Date')
    ax.set_ylabel('NDVI')
    ax.legend()
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# train rows
train_df = df_all[df_all['type'] == 'train']

# test rows
test_df = df_all[df_all['type'] == 'test']

# target
y_train = train_df['total_cases']

# training features
X_train = train_df.drop(columns=['total_cases', 'week_start_date', 'type'])

# competition test features
X_test = test_df.drop(columns=['total_cases' ,'week_start_date', 'type'])


#  
# San Juan
train_sj = train_df[train_df['city'] == 0]

X_train_sj = train_sj.drop(columns=['total_cases', 'week_start_date', 'type'])
y_train_sj = train_sj['total_cases']
X_test_sj = test_df[test_df['city'] == 0]
X_test_sj = train_sj.drop(columns=['total_cases', 'week_start_date', 'type'])



# Iquitos
train_iq = train_df[train_df['city'] == 1]

X_train_iq = train_iq.drop(columns=['total_cases', 'week_start_date', 'type'])
y_train_iq = train_iq['total_cases']

# %%
X_train_sj.head()
# Out:
#   city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0    0  1990          18  0.122600  0.103725  0.198483  0.177617
# 1    0  1990          19  0.169900  0.142175  0.162357  0.155486
# 2    0  1990          20  0.032250  0.172967  0.157200  0.170843
# 3    0  1990          21  0.128633  0.245067  0.227557  0.235886
# 4    0  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  ...  \
# 0                 12.42             297.572857             297.742857  ...
# 1                 22.82             298.211429             298.442857  ...
# 2                 34.54             298.781429             298.878571  ...
# 3                 15.36             298.987143             299.228571  ...
# 4                  7.52             299.518571             299.664286  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# ── Fit ───────────────────────────────────────────────────────────────────────

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train_sj, y_train_sj)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.predict(X_test_sj)
# Out:
# array([  6.17,   5.83,   4.59,   4.5 ,   6.72,   4.88,   4.68,   7.26,
#          8.9 ,   6.78,   7.48,   5.05,  12.6 ,  25.47,  31.14,  22.87,
#         34.34,  34.66,  40.9 ,  31.45,  41.05,  38.53,  47.26,  41.87,
#         42.77,  45.97,  56.57,  63.83,  52.77,  52.15,  53.57,  57.5 ,
#         47.32,  36.84,  38.77,  33.96,  23.67,  27.53,  40.35,  37.86,
#         22.32,  24.86,  25.35,  21.78,  23.65,  18.17,  17.87,  16.48,
#         16.77,  19.14,  20.45,  16.48,  17.57,  13.62,  17.05,  11.98,
#         16.33,  20.12,  21.51,  16.82,  18.55,  15.26,  16.31,  20.42,
#         29.08,  33.54,  61.05,  73.37,  76.24,  65.51,  61.81,  71.7 ,
#         83.84,  86.54, 113.46, 112.1 , 122.86, 111.44, 122.18, 124.92,
#        121.73, 113.27, 144.29, 127.71, 109.56,  79.03,  74.47,  58.8 ,
#         77.24,  67.74,  68.54,  47.74,  47.11,  55.94,  35.31,  36.76,
#         45.96,  34.53,  32.15,  25.82,  26.88,  28.21,  25.75,  23.78,
# ...
